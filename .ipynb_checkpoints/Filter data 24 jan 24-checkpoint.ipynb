# %%
import pandas as pd
import numpy as np

# %%
data_jualan=pd.read_excel("data_penjualan-copy.xlsx")
data_jualan
# Out:
#          Tanggal      Jenis Produk  Jumlah Order   Harga      Total
# 0     05/08/2022        Foodpak260        1000.0  1800.0  1800000.0
# 1     05/08/2022   FoodpakMatte245        1000.0  1900.0  1900000.0
# 2     05/08/2022  CraftLaminasi290        5000.0   750.0  3750000.0
# 3     05/08/2022  CraftLaminasi290        1000.0  1200.0  1200000.0
# 4     07/08/2022        Dupleks310        1000.0  1550.0  1550000.0
# ...          ...               ...           ...     ...        ...
# 1071  14/11/2023          Ivory230        1000.0   900.0   900000.0
# 1072  15/11/2023  CraftLaminasi290        2000.0   800.0  1600000.0
# 1073  15/11/2023  CraftLaminasi290        1500.0   875.0  1312500.0
# 1074  15/11/2023      FoodpakMatte        1000.0  2200.0  2200000.0
# 1075  15/11/2023       GreaseProof        1000.0   300.0   300000.0
#
# [1076 rows x 5 columns]

# %%
harus mengubah datatime menjedi formatnya(day-month-year)
jenis product-object-astype(str)

# %%
#data cleansing missing value
data_jualan.isna().sum()
# Out:
# Tanggal          0
# Jenis Produk    20
# Jumlah Order    45
# Harga           52
# Total           54
# dtype: int64

# %%
tanggal 0
jenis produk 20 --- modus()
jumlah ordeer 45--- mean()
harga 52 ---- mean()
total 54 --- hasil kali dengan jumlah order*harga

# %%
data_jualan["Jenis Produk"].fillna(data_jualan["Jenis Produk"].mode()[0], inplace=True)
# Out:
# C:\Users\gilan\AppData\Local\Temp\ipykernel_7332\3211667542.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_jualan["Jenis Produk"].fillna(data_jualan["Jenis Produk"].mode()[0], inplace=True)

# %%
data_jualan["Jumlah Order"].fillna(data_jualan["Jumlah Order"].mean(),inplace=True)
# Out:
# C:\Users\gilan\AppData\Local\Temp\ipykernel_7332\3158203600.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_jualan["Jumlah Order"].fillna(data_jualan["Jumlah Order"].mean(),inplace=True)

# %%
data_jualan["Harga"].fillna(data_jualan["Harga"].mean(), inplace=True)
# Out:
# C:\Users\gilan\AppData\Local\Temp\ipykernel_7332\908935075.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_jualan["Harga"].fillna(data_jualan["Harga"].mean(), inplace=True)

# %%
data_jualan.loc[data-jualan["Total".isna(),"Total"]=data_jualan.fillna(data_jualan["Jumlah Order"].mean()[0], inplece=True)

# %%
data_jualan["Total"] = data_jualan["Total"].fillna(data_jualan["Jumlah Order"] * data_jualan["Harga"])

# %%
data_jualan.isna().sum
# Out:
# <bound method DataFrame.sum of       Tanggal  Jenis Produk  Jumlah Order  Harga  Total  Jualan Produk
# 0       False         False         False  False  False          False
# 1       False         False         False  False  False          False
# 2       False         False         False  False  False          False
# 3       False         False         False  False  False          False
# 4       False         False         False  False  False          False
# ...       ...           ...           ...    ...    ...            ...
# 1071    False         False         False  False  False          False
# 1072    False         False         False  False  False          False
# 1073    False         False         False  False  False          False
# 1074    False         False         False  False  False          False
# 1075    False         False         False  False  False          False
#
# [1076 rows x 6 columns]>

# %%
#3. preprosesing data

# %%
data_jualan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1076 entries, 0 to 1075
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tanggal       1076 non-null   object
#  1   Jenis Produk  1076 non-null   object
#  2   Jumlah Order  1031 non-null   float64
#  3   Harga         1024 non-null   float64
#  4   Total         1073 non-null   float64
# dtypes: float64(3), object(2)
# memory usage: 42.2+ KB

# %%
#mengubah object menjadi sering object
data_jualan["Jualan Produk"] = data_jualan["Jenis Produk"].astype(str)

# %%
data_jualan["Tanggal"] = pd.to_datetime(data_jualan["Tanggal"],format="%d/%m/%Y")

# %%
data_jualan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1076 entries, 0 to 1075
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tanggal        1076 non-null   datetime64[ns]
#  1   Jenis Produk   1076 non-null   object
#  2   Jumlah Order   1031 non-null   float64
#  3   Harga          1024 non-null   float64
#  4   Total          1073 non-null   float64
#  5   Jualan Produk  1076 non-null   object
# dtypes: datetime64[ns](1), float64(3), object(2)
# memory usage: 50.6+ KB

# %%
Kalo buat mencari total penjualn di bulan dan tahun tertentu gimana ka kaya tugas kemarin bulan 10 2023

# %%
data_jualan
# Out:
#         Tanggal      Jenis Produk  Jumlah Order   Harga      Total  \
# 0    2022-08-05        Foodpak260        1000.0  1800.0  1800000.0
# 1    2022-08-05   FoodpakMatte245        1000.0  1900.0  1900000.0
# 2    2022-08-05  CraftLaminasi290        5000.0   750.0  3750000.0
# 3    2022-08-05  CraftLaminasi290        1000.0  1200.0  1200000.0
# 4    2022-08-07        Dupleks310        1000.0  1550.0  1550000.0
# ...         ...               ...           ...     ...        ...
# 1071 2023-11-14          Ivory230        1000.0   900.0   900000.0
# 1072 2023-11-15  CraftLaminasi290        2000.0   800.0  1600000.0
# 1073 2023-11-15  CraftLaminasi290        1500.0   875.0  1312500.0
# 1074 2023-11-15      FoodpakMatte        1000.0  2200.0  2200000.0
# 1075 2023-11-15       GreaseProof        1000.0   300.0   300000.0
#
#          Jualan Produk
# 0           Foodpak260
# 1      FoodpakMatte245
# 2     CraftLaminasi290
# 3     CraftLaminasi290
# 4           Dupleks310
# ...

# %%
#3.1 FILTERISASI DATA

# %%
data_jualan["Jenis Produk"].unique()
# Out:
# array(['Foodpak260', 'FoodpakMatte245', 'CraftLaminasi290', 'Dupleks310',
#        'Ivory270', 'Kinstruk130', 'HVS', 'Dupleks350', 'CraftLaminasi',
#        'GRESSPROFF', 'Ivory230+LaminasiDoff', '260Glossy',
#        'CraftFoodpak290', 'Ivory230', 'Dupleks270', 'Kinstruk150',
#        'FoodpakGlossy', 'Dupleks270Eplex', 'Ivory250', 'GreaseProof',
#        'Foodpak295Matte', 'Foodpak260Glossy', 'Ivory300',
#        'FoodpakGlossy260', 'Foodpak295', 'Dupleks400', 'FoodpakMatte295',
#        'GreaseProof40', 'GreaseProofPlano', 'Dupleks270Laminating',
#        'PTSariIndahPackagingIndustry', 'Craft310', 'Dupleks310P',
#        'Craft290', 'Ivory250+Laminasi', 'StikerA3',
#        'Ivory230+LaminasiAlas', 'CraftBiasa310', 'Ivory230+Laminating',
#        'Ivory260Matte', 'Craft290Laminasi', 'Foodpak260Matte', 'Craft300',
#        'DUPLEKS310', 'KertasSisaIvory300', 'CraftFoodpak290Laminasi',
#        'Ivory350', 'FoodpakGlossy320', 'Craft270', 'PTSARIINDAH',
# ...

# %% [markdown]
# filterisasi jenis produk dupleks270 di 2 tahun (2022 dan 2023)

# %%
filter_data1 = data_jualan.copy()

# %%
filter_data1 = filter_data1[filter_data1["Jenis Produk"]=="Dupleks270"]
filter_data1
# Out:
#         Tanggal Jenis Produk  Jumlah Order        Harga      Total  \
# 30   2022-08-15   Dupleks270        1000.0  1900.000000  1900000.0
# 35   2022-08-18   Dupleks270         500.0  1713.202148  1100000.0
# 83   2022-09-14   Dupleks270        1000.0  1800.000000  1800000.0
# 203  2022-11-22   Dupleks270        1000.0  1800.000000  1800000.0
# 252  2022-12-07   Dupleks270        1000.0  1500.000000  1500000.0
# 271  2022-12-14   Dupleks270        1000.0  2000.000000  2000000.0
# 344  2023-01-06   Dupleks270        1000.0  1500.000000  1500000.0
# 451  2023-03-06   Dupleks270        2500.0  1700.000000  4250000.0
# 505  2023-04-04   Dupleks270        1000.0  1600.000000  1600000.0
# 564  2023-05-04   Dupleks270        1000.0  1400.000000  1400000.0
# 565  2023-05-04   Dupleks270         500.0  1800.000000   900000.0
# 621  2023-05-29   Dupleks270        1000.0  1900.000000  1900000.0
# 718  2023-07-10   Dupleks270        3000.0  1800.000000  5400000.0
# ...

# %%
#menambahkan filter bulan
filter_data1["Bulan"] = filter_data1["Tanggal"].dt.month_name()
filter_data1
# Out:
#         Tanggal Jenis Produk  Jumlah Order        Harga      Total  \
# 30   2022-08-15   Dupleks270        1000.0  1900.000000  1900000.0
# 35   2022-08-18   Dupleks270         500.0  1713.202148  1100000.0
# 83   2022-09-14   Dupleks270        1000.0  1800.000000  1800000.0
# 203  2022-11-22   Dupleks270        1000.0  1800.000000  1800000.0
# 252  2022-12-07   Dupleks270        1000.0  1500.000000  1500000.0
# 271  2022-12-14   Dupleks270        1000.0  2000.000000  2000000.0
# 344  2023-01-06   Dupleks270        1000.0  1500.000000  1500000.0
# 451  2023-03-06   Dupleks270        2500.0  1700.000000  4250000.0
# 505  2023-04-04   Dupleks270        1000.0  1600.000000  1600000.0
# 564  2023-05-04   Dupleks270        1000.0  1400.000000  1400000.0
# 565  2023-05-04   Dupleks270         500.0  1800.000000   900000.0
# 621  2023-05-29   Dupleks270        1000.0  1900.000000  1900000.0
# 718  2023-07-10   Dupleks270        3000.0  1800.000000  5400000.0
# ...

# %%
penghasilan2_periode_data1 = filter_data1.groupby("Bulan").agg(
total_order = ("Jumlah Order","sum"),
total_pendapatan = ("Total","sum")
).reindex(['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'])

# %%
penghasilan2_periode_data1
# Out:
#            total_order  total_pendapatan
# Bulan
# January         1000.0         1500000.0
# February           NaN               NaN
# March           2500.0         4250000.0
# April           1000.0         1600000.0
# May             2500.0         4200000.0
# June               NaN               NaN
# July            6000.0         9600000.0
# August         12500.0        21600000.0
# September       6000.0         8800000.0
# October         3000.0         4700000.0
# November        6000.0         9400000.0
# December        2000.0         3500000.0

# %%
filter_data1["Tahun"] = filter_data1["Tanggal"].dt.year
filter_data1
# Out:
#         Tanggal Jenis Produk  Jumlah Order        Harga      Total  \
# 30   2022-08-15   Dupleks270        1000.0  1900.000000  1900000.0
# 35   2022-08-18   Dupleks270         500.0  1713.202148  1100000.0
# 83   2022-09-14   Dupleks270        1000.0  1800.000000  1800000.0
# 203  2022-11-22   Dupleks270        1000.0  1800.000000  1800000.0
# 252  2022-12-07   Dupleks270        1000.0  1500.000000  1500000.0
# 271  2022-12-14   Dupleks270        1000.0  2000.000000  2000000.0
# 344  2023-01-06   Dupleks270        1000.0  1500.000000  1500000.0
# 451  2023-03-06   Dupleks270        2500.0  1700.000000  4250000.0
# 505  2023-04-04   Dupleks270        1000.0  1600.000000  1600000.0
# 564  2023-05-04   Dupleks270        1000.0  1400.000000  1400000.0
# 565  2023-05-04   Dupleks270         500.0  1800.000000   900000.0
# 621  2023-05-29   Dupleks270        1000.0  1900.000000  1900000.0
# 718  2023-07-10   Dupleks270        3000.0  1800.000000  5400000.0
# ...

# %%
filter_data1
# Out:
#         Tanggal Jenis Produk  Jumlah Order        Harga      Total  \
# 30   2022-08-15   Dupleks270        1000.0  1900.000000  1900000.0
# 35   2022-08-18   Dupleks270         500.0  1713.202148  1100000.0
# 83   2022-09-14   Dupleks270        1000.0  1800.000000  1800000.0
# 203  2022-11-22   Dupleks270        1000.0  1800.000000  1800000.0
# 252  2022-12-07   Dupleks270        1000.0  1500.000000  1500000.0
# 271  2022-12-14   Dupleks270        1000.0  2000.000000  2000000.0
# 344  2023-01-06   Dupleks270        1000.0  1500.000000  1500000.0
# 451  2023-03-06   Dupleks270        2500.0  1700.000000  4250000.0
# 505  2023-04-04   Dupleks270        1000.0  1600.000000  1600000.0
# 564  2023-05-04   Dupleks270        1000.0  1400.000000  1400000.0
# 565  2023-05-04   Dupleks270         500.0  1800.000000   900000.0
# 621  2023-05-29   Dupleks270        1000.0  1900.000000  1900000.0
# 718  2023-07-10   Dupleks270        3000.0  1800.000000  5400000.0
# ...

# %%
penghasilan2_periode_data1 = filter_data1.groupby("Bulan").agg(
total_order = ("Jumlah Order","sum"),
total_pendapatan = ("Total","sum")
).reindex(['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'])

# %%
penghasilan2_periode_data1
# Out:
#            total_order  total_pendapatan
# Bulan
# January         1000.0         1500000.0
# February           NaN               NaN
# March           2500.0         4250000.0
# April           1000.0         1600000.0
# May             2500.0         4200000.0
# June               NaN               NaN
# July            6000.0         9600000.0
# August         12500.0        21600000.0
# September       6000.0         8800000.0
# October         3000.0         4700000.0
# November        6000.0         9400000.0
# December        2000.0         3500000.0

# %%
filter_data2 = data_jualan.copy()

# %%
filter_data2 = filter_data2[(filter_data2["Jenis Produk"]=="Dupleks270") & (filter_data2["Total"]>3000000)]
filter_data2
# Out:
#         Tanggal Jenis Produk  Jumlah Order   Harga      Total Jualan Produk
# 451  2023-03-06   Dupleks270        2500.0  1700.0  4250000.0    Dupleks270
# 718  2023-07-10   Dupleks270        3000.0  1800.0  5400000.0    Dupleks270
# 719  2023-07-11   Dupleks270        3000.0  1400.0  4200000.0    Dupleks270
# 799  2023-08-07   Dupleks270        4000.0  1800.0  7200000.0    Dupleks270
# 800  2023-08-07   Dupleks270        4000.0  1400.0  5600000.0    Dupleks270
# 928  2023-09-20   Dupleks270        5000.0  1400.0  7000000.0    Dupleks270
# 1041 2023-11-06   Dupleks270        4000.0  1400.0  5600000.0    Dupleks270

# %%
filterdata 3 --- dupleks310
filterdata3 --- dupleks310 and total > 100000

# %% [raw]
# filterdata4_single---hvs
# dilter_data4_dobel--- hvs and jumlah order > 1000

# %%
filter_data3_single = data_jualan.copy()

# %%
filter_data3_single = filter_data3_single[filter_data3_single["Jenis Produk"]=="Dupleks310"]
filter_data3_single
# Out:
#         Tanggal Jenis Produk  Jumlah Order   Harga      Total Jualan Produk
# 4    2022-08-07   Dupleks310        1000.0  1550.0  1550000.0    Dupleks310
# 5    2022-08-08   Dupleks310         500.0  1900.0   950000.0    Dupleks310
# 11   2022-08-10   Dupleks310         500.0  1600.0   800000.0    Dupleks310
# 16   2022-08-11   Dupleks310        2000.0  1300.0  2600000.0    Dupleks310
# 19   2022-08-12   Dupleks310        1000.0  2200.0  2200000.0    Dupleks310
# ...         ...          ...           ...     ...        ...           ...
# 1024 2023-10-28   Dupleks310        1000.0  1700.0  1700000.0    Dupleks310
# 1037 2023-11-03   Dupleks310        2000.0  1600.0  3200000.0    Dupleks310
# 1054 2023-11-09   Dupleks310        1000.0  1500.0  1500000.0    Dupleks310
# 1057 2023-11-11   Dupleks310        1000.0  1900.0  1900000.0    Dupleks310
# 1058 2023-11-11   Dupleks310        1000.0  1900.0  1900000.0    Dupleks310
#
# [180 rows x 6 columns]

# %%
filter_data3_dobel = data_jualan.copy()

# %%
filter_data3_dobel= filter_data3_dobel[(filter_data3_dobel["Jenis Produk"]=="Dupleks310") & (filter_data3_dobel["Total"]>100000)]
filter_data3_dobel
# Out:
#         Tanggal Jenis Produk  Jumlah Order   Harga      Total Jualan Produk
# 4    2022-08-07   Dupleks310        1000.0  1550.0  1550000.0    Dupleks310
# 5    2022-08-08   Dupleks310         500.0  1900.0   950000.0    Dupleks310
# 11   2022-08-10   Dupleks310         500.0  1600.0   800000.0    Dupleks310
# 16   2022-08-11   Dupleks310        2000.0  1300.0  2600000.0    Dupleks310
# 19   2022-08-12   Dupleks310        1000.0  2200.0  2200000.0    Dupleks310
# ...         ...          ...           ...     ...        ...           ...
# 1024 2023-10-28   Dupleks310        1000.0  1700.0  1700000.0    Dupleks310
# 1037 2023-11-03   Dupleks310        2000.0  1600.0  3200000.0    Dupleks310
# 1054 2023-11-09   Dupleks310        1000.0  1500.0  1500000.0    Dupleks310
# 1057 2023-11-11   Dupleks310        1000.0  1900.0  1900000.0    Dupleks310
# 1058 2023-11-11   Dupleks310        1000.0  1900.0  1900000.0    Dupleks310
#
# [179 rows x 6 columns]

# %%
filter_data3_dobel["Bulan"] = filter_data3_dobel["Tanggal"].dt.month_name()
filter_data3_dobel
# Out:
#         Tanggal Jenis Produk  Jumlah Order   Harga      Total Jualan Produk  \
# 4    2022-08-07   Dupleks310        1000.0  1550.0  1550000.0    Dupleks310
# 5    2022-08-08   Dupleks310         500.0  1900.0   950000.0    Dupleks310
# 11   2022-08-10   Dupleks310         500.0  1600.0   800000.0    Dupleks310
# 16   2022-08-11   Dupleks310        2000.0  1300.0  2600000.0    Dupleks310
# 19   2022-08-12   Dupleks310        1000.0  2200.0  2200000.0    Dupleks310
# ...         ...          ...           ...     ...        ...           ...
# 1024 2023-10-28   Dupleks310        1000.0  1700.0  1700000.0    Dupleks310
# 1037 2023-11-03   Dupleks310        2000.0  1600.0  3200000.0    Dupleks310
# 1054 2023-11-09   Dupleks310        1000.0  1500.0  1500000.0    Dupleks310
# 1057 2023-11-11   Dupleks310        1000.0  1900.0  1900000.0    Dupleks310
# 1058 2023-11-11   Dupleks310        1000.0  1900.0  1900000.0    Dupleks310
#
#          Bulan
# 4       August
# 5       August
# ...

# %%
filter_data3_dobel["Tahun"] = filter_data3_dobel["Tanggal"].dt.year
filter_data3_dobel
# Out:
#         Tanggal Jenis Produk  Jumlah Order   Harga      Total Jualan Produk  \
# 4    2022-08-07   Dupleks310        1000.0  1550.0  1550000.0    Dupleks310
# 5    2022-08-08   Dupleks310         500.0  1900.0   950000.0    Dupleks310
# 11   2022-08-10   Dupleks310         500.0  1600.0   800000.0    Dupleks310
# 16   2022-08-11   Dupleks310        2000.0  1300.0  2600000.0    Dupleks310
# 19   2022-08-12   Dupleks310        1000.0  2200.0  2200000.0    Dupleks310
# ...         ...          ...           ...     ...        ...           ...
# 1024 2023-10-28   Dupleks310        1000.0  1700.0  1700000.0    Dupleks310
# 1037 2023-11-03   Dupleks310        2000.0  1600.0  3200000.0    Dupleks310
# 1054 2023-11-09   Dupleks310        1000.0  1500.0  1500000.0    Dupleks310
# 1057 2023-11-11   Dupleks310        1000.0  1900.0  1900000.0    Dupleks310
# 1058 2023-11-11   Dupleks310        1000.0  1900.0  1900000.0    Dupleks310
#
#          Bulan  Tahun
# 4       August   2022
# ...

# %%
import matplotlib.pyplot as plt

# %%
penghasilan2_periode_data3 = filter_data3_dobel.groupby("Bulan").agg(
total_order = ("Jumlah Order","sum"),
total_pendapatan = ("Total","sum")
).reindex(['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'])

# %%
penghasilan2_periode_data3
# Out:
#             total_order  total_pendapatan
# Bulan
# January    32500.000000        54100000.0
# February    3915.332687         7500000.0
# March      11500.000000        19500000.0
# April      10500.000000        17900000.0
# May        11000.000000        17900000.0
# June       13000.000000        19900000.0
# July       18915.332687        32900000.0
# August     59076.663434       104845000.0
# September  42415.332687        65125000.0
# October    28600.000000        47145000.0
# November   17000.000000        28400000.0
# December   13915.332687        21650000.0

# %%
#membuat canvas
plt.figure(figsize=(20,10))

#deklarasi colorrs untuk memberikan warna legenda lebih dari 1
colors = plt.cm.tab20.colors

#membuat barchart dengan masukan data x dan y, lalu memberikan label pada data serta menyeting warna setiap kkolom X
plt.bar(penghasilan2_periode_data3 .index, penghasilan2_periode_data3 ["total_order"], label=penghasilan2_periode_data3 .index, color=colors[:len(penghasilan2_periode_data3.index)])

#kasih title
plt.title("Total Order Data 3",fontsize=25)

#label untuk X dan Y
plt.xlabel("BULAN",fontsize=25)
plt.ylabel("Total Order",fontsize=25)

#kasih rotasi (opsional)
plt.xticks(rotation=45)
plt.yticks(rotation=45)

#aktifkan si legend
plt.legend(penghasilan2_periode_data3 .index, title="Bulan", loc="upper right")
#plt.grid(True)
plt.show()

# %%
#membuat canvas
plt.figure(figsize=(20,10))

#deklarasi colorrs untuk memberikan warna legenda lebih dari 1
colors = plt.cm.tab20.colors

#membuat barchart dengan masukan data x dan y, lalu memberikan label pada data serta menyeting warna setiap kkolom X
plt.bar(penghasilan2_periode_data3 .index, penghasilan2_periode_data3 ["total_pendapatan"], label=penghasilan2_periode_data3 .index, color=colors[:len(penghasilan2_periode_data3.index)])

#kasih title
plt.title("Total pendapatan Data 3",fontsize=25)

#label untuk X dan Y
plt.xlabel("BULAN",fontsize=25)
plt.ylabel("Total Pendapatan",fontsize=25)

#kasih rotasi (opsional)
plt.xticks(rotation=45)
plt.yticks(rotation=45)

#aktifkan si legend
plt.legend(penghasilan2_periode_data3 .index, title="Bulan", loc="upper right")
#plt.grid(True)
plt.show()

# %%
filter_data4_single = data_jualan.copy()

# %%
filter_data4_single = filter_data4_single[filter_data4_single["Jenis Produk"]=="HVS"]
filter_data4_single
# Out:
#         Tanggal Jenis Produk  Jumlah Order        Harga       Total  \
# 8    2022-08-09          HVS        1500.0  1713.202148   1275000.0
# 62   2022-09-03          HVS       20000.0   250.000000   5000000.0
# 128  2022-10-07          HVS       20000.0   250.000000   5000000.0
# 197  2022-11-20          HVS       20000.0   250.000000   5000000.0
# 256  2022-12-07          HVS       20000.0   250.000000   5000000.0
# 345  2023-01-06          HVS       20000.0   250.000000   5000000.0
# 431  2023-02-21          HVS       40000.0   250.000000  10000000.0
# 547  2023-04-29          HVS       20000.0   250.000000   5000000.0
# 570  2023-05-05          HVS        2000.0   250.000000    500000.0
# 684  2023-06-26          HVS       20000.0   250.000000   5000000.0
# 836  2023-08-20          HVS        5000.0   300.000000   1500000.0
# 850  2023-08-24          HVS       20000.0   250.000000   5000000.0
# 968  2023-10-08          HVS       10000.0   275.000000   2750000.0
# ...

# %%
filter_data4_dobel = data_jualan.copy()

# %%
filter_data4_dobel= filter_data4_dobel[(filter_data4_dobel["Jenis Produk"]=="HVS") & (filter_data4_dobel["Jumlah Order"]>1000)]
filter_data4_dobel
# Out:
#         Tanggal Jenis Produk  Jumlah Order        Harga       Total  \
# 8    2022-08-09          HVS        1500.0  1713.202148   1275000.0
# 62   2022-09-03          HVS       20000.0   250.000000   5000000.0
# 128  2022-10-07          HVS       20000.0   250.000000   5000000.0
# 197  2022-11-20          HVS       20000.0   250.000000   5000000.0
# 256  2022-12-07          HVS       20000.0   250.000000   5000000.0
# 345  2023-01-06          HVS       20000.0   250.000000   5000000.0
# 431  2023-02-21          HVS       40000.0   250.000000  10000000.0
# 547  2023-04-29          HVS       20000.0   250.000000   5000000.0
# 570  2023-05-05          HVS        2000.0   250.000000    500000.0
# 684  2023-06-26          HVS       20000.0   250.000000   5000000.0
# 836  2023-08-20          HVS        5000.0   300.000000   1500000.0
# 850  2023-08-24          HVS       20000.0   250.000000   5000000.0
# 968  2023-10-08          HVS       10000.0   275.000000   2750000.0
# ...

# %%
filter_data4_dobel["Bulan"] = filter_data4_dobel["Tanggal"].dt.month_name()
filter_data4_dobel
# Out:
#         Tanggal Jenis Produk  Jumlah Order        Harga       Total  \
# 8    2022-08-09          HVS        1500.0  1713.202148   1275000.0
# 62   2022-09-03          HVS       20000.0   250.000000   5000000.0
# 128  2022-10-07          HVS       20000.0   250.000000   5000000.0
# 197  2022-11-20          HVS       20000.0   250.000000   5000000.0
# 256  2022-12-07          HVS       20000.0   250.000000   5000000.0
# 345  2023-01-06          HVS       20000.0   250.000000   5000000.0
# 431  2023-02-21          HVS       40000.0   250.000000  10000000.0
# 547  2023-04-29          HVS       20000.0   250.000000   5000000.0
# 570  2023-05-05          HVS        2000.0   250.000000    500000.0
# 684  2023-06-26          HVS       20000.0   250.000000   5000000.0
# 836  2023-08-20          HVS        5000.0   300.000000   1500000.0
# 850  2023-08-24          HVS       20000.0   250.000000   5000000.0
# 968  2023-10-08          HVS       10000.0   275.000000   2750000.0
# ...

# %%
filter_data4_dobel["Tahun"] = filter_data4_dobel["Tanggal"].dt.year
filter_data4_dobel
# Out:
#         Tanggal Jenis Produk  Jumlah Order        Harga       Total  \
# 8    2022-08-09          HVS        1500.0  1713.202148   1275000.0
# 62   2022-09-03          HVS       20000.0   250.000000   5000000.0
# 128  2022-10-07          HVS       20000.0   250.000000   5000000.0
# 197  2022-11-20          HVS       20000.0   250.000000   5000000.0
# 256  2022-12-07          HVS       20000.0   250.000000   5000000.0
# 345  2023-01-06          HVS       20000.0   250.000000   5000000.0
# 431  2023-02-21          HVS       40000.0   250.000000  10000000.0
# 547  2023-04-29          HVS       20000.0   250.000000   5000000.0
# 570  2023-05-05          HVS        2000.0   250.000000    500000.0
# 684  2023-06-26          HVS       20000.0   250.000000   5000000.0
# 836  2023-08-20          HVS        5000.0   300.000000   1500000.0
# 850  2023-08-24          HVS       20000.0   250.000000   5000000.0
# 968  2023-10-08          HVS       10000.0   275.000000   2750000.0
# ...

# %%
penghasilan2_periode_data4 = filter_data4_dobel.groupby("Bulan").agg(
total_order = ("Jumlah Order","sum"),
total_pendapatan = ("Total","sum")
).reindex(['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'])

# %%
penghasilan2_periode_data4
# Out:
#            total_order  total_pendapatan
# Bulan
# January        20000.0         5000000.0
# February       40000.0        10000000.0
# March              NaN               NaN
# April          20000.0         5000000.0
# May             2000.0          500000.0
# June           20000.0         5000000.0
# July               NaN               NaN
# August         26500.0         7775000.0
# September      20000.0         5000000.0
# October        50000.0        12750000.0
# November       20000.0         5000000.0
# December       20000.0         5000000.0

# %%
#membuat canvas
plt.figure(figsize=(15,10))

#deklarasi colorrs untuk memberikan warna legenda lebih dari 1
colors = plt.cm.tab20.colors

#membuat barchart dengan masukan data x dan y, lalu memberikan label pada data serta menyeting warna setiap kkolom X
plt.bar(penghasilan2_periode_data4 .index, penghasilan2_periode_data4 ["total_pendapatan"], label=penghasilan2_periode_data4 .index, color=colors[:len(penghasilan2_periode_data4.index)])

#kasih title
plt.title("Total Pendapatan Data 4",fontsize=25)

#label untuk X dan Y
plt.xlabel("BULAN",fontsize=25)
plt.ylabel("Total Pendapatan",fontsize=25)

#kasih rotasi (opsional)
plt.xticks(rotation=45)
plt.yticks(rotation=45)

#aktifkan si legend
plt.legend(penghasilan2_periode_data4 .index, title="Bulan", loc="upper right")
#plt.grid(True)
plt.show()

# %%
#membuat canvas
plt.figure(figsize=(15,10))

#deklarasi colorrs untuk memberikan warna legenda lebih dari 1
colors = plt.cm.tab20.colors

#membuat barchart dengan masukan data x dan y, lalu memberikan label pada data serta menyeting warna setiap kkolom X
plt.bar(penghasilan2_periode_data4 .index, penghasilan2_periode_data4 ["total_order"], label=penghasilan2_periode_data4 .index, color=colors[:len(penghasilan2_periode_data4.index)])

#kasih title
plt.title("Total Order Data 4",fontsize=25)

#label untuk X dan Y
plt.xlabel("BULAN",fontsize=25)
plt.ylabel("Total Order",fontsize=25)

#kasih rotasi (opsional)
plt.xticks(rotation=45)
plt.yticks(rotation=45)

#aktifkan si legend
plt.legend(penghasilan2_periode_data4 .index, title="Bulan", loc="upper right")
#plt.grid(True)
plt.show()
